# %%
import pandas as pd
import numpy as np
import copy

df = pd.DataFrame.from_csv('dataset_mood_smartphone.csv')
# Out:
# /home/jordan/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """

# %%
df
# Out:
#               id                     time        variable    value
# 1        AS14.01  2014-02-26 13:00:00.000            mood    6.000
# 2        AS14.01  2014-02-26 15:00:00.000            mood    6.000
# 3        AS14.01  2014-02-26 18:00:00.000            mood    6.000
# 4        AS14.01  2014-02-26 21:00:00.000            mood    7.000
# 5        AS14.01  2014-02-27 09:00:00.000            mood    6.000
# 6        AS14.01  2014-02-27 12:00:00.000            mood    6.000
# 7        AS14.01  2014-02-27 15:00:00.000            mood    7.000
# 8        AS14.01  2014-03-21 09:00:00.000            mood    6.000
# 9        AS14.01  2014-03-21 11:00:00.000            mood    6.000
# 10       AS14.01  2014-03-21 15:00:00.000            mood    7.000
# 11       AS14.01  2014-03-21 19:00:00.000            mood    6.000
# 12       AS14.01  2014-03-21 21:00:00.000            mood    6.000
# 13       AS14.01  2014-03-22 08:00:00.000            mood    7.000
# ...

# %%
uniq = df['id'].unique()
print(len(uniq))
# Out:
# 27

# %%
df = pd.DataFrame.from_csv('dataset_mood_smartphone.csv')
df['time'] = pd.to_datetime(df['time']) 
df = df.set_index(['id', 'time'])
df = pd.pivot_table(df, index=['id', 'time'], columns='variable', values='value')
df
# Out:
# /home/jordan/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
# variable                         activity  appCat.builtin  \
# id      time
# AS14.01 2014-02-17 12:04:42.394       NaN             NaN
#         2014-02-17 18:28:25.520       NaN             NaN
#         2014-02-18 09:29:51.257       NaN             NaN
#         2014-02-19 14:43:30.575       NaN             NaN
#         2014-02-19 17:29:10.378       NaN             NaN
#         2014-02-19 17:42:16.499       NaN             NaN
#         2014-02-19 17:42:34.292       NaN             NaN
#         2014-02-19 17:43:18.061       NaN             NaN
#         2014-02-19 17:44:01.594       NaN             NaN
# ...

# %%
for i in range(0, len(df)):
    print(df.index[i][0])
# Out:
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# AS14.01
# ...

# %%
df_list  = []
df_master = pd.DataFrame(columns = df.columns)
df_dict  = {}
for i_d in uniq:
    print(i_d)
    df_tmp = df.loc[df['id']== i_d]
    #df_tmp = df_tmp.sort_values(by = ['time'])
    dt_tmp = dt_tmp.set_index(['id', 'time'])
    dt_tmp = pd.pivot_table(df_tmp, index=['id', 'time'], columns='variable', values='value')
    df_list.append(copy.deepcopy(df_tmp))
    df_master = pd.concat([df_master, copy.deepcopy(df_tmp)], ignore_index = True)
    df_dict[i_d] = copy.deepcopy(df_tmp)
    print(df_list[-1]['time'].min())
    print(df_list[-1]['time'].max())
# Out:
# AS14.01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-09ad1cc09740> in <module>()
#       7 for i_d in uniq:
#       8     print(i_d)
# ----> 9     df_tmp = df.loc[df['id']== i_d]
#      10     #df_tmp = df_tmp.sort_values(by = ['time'])
#      11     dt_tmp = dt_tmp.set_index(['id', 'time'])
#
# /home/jordan/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /home/jordan/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
# ...

# %%
df_list[0]
# Out:
#               id                    time              variable      value
# 136471   AS14.01 2014-02-17 12:04:42.394                  call   1.000000
# 136472   AS14.01 2014-02-17 18:28:25.520                  call   1.000000
# 136473   AS14.01 2014-02-18 09:29:51.257                  call   1.000000
# 136474   AS14.01 2014-02-19 14:43:30.575                  call   1.000000
# 136475   AS14.01 2014-02-19 17:29:10.378                  call   1.000000
# 136476   AS14.01 2014-02-19 17:42:16.499                  call   1.000000
# 141710   AS14.01 2014-02-19 17:42:34.292                   sms   1.000000
# 136477   AS14.01 2014-02-19 17:43:18.061                  call   1.000000
# 136478   AS14.01 2014-02-19 17:44:01.594                  call   1.000000
# 136479   AS14.01 2014-02-19 18:07:50.055                  call   1.000000
# 136480   AS14.01 2014-02-19 18:10:06.385                  call   1.000000
# 141711   AS14.01 2014-02-19 21:25:04.397                   sms   1.000000
# ...

# %%
# Out:
#   File "<ipython-input-14-be59c3742690>", line 1
#     df_dict{0}
#            ^
# SyntaxError: invalid syntax
